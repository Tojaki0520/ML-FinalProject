# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

import random
import os
import cv2
from tqdm import tqdm

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.models import Model
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions

from PIL import Image
from PIL import ImageFilter

# %%
# Helper function to do one hot encoding for labels
def encode_label(labels):
    target = np.zeros(9, dtype='int')
    for l in labels:
        target[l] = 1
    return target
def encode_new_label(labels):
    target = np.zeros(5, dtype='int')
    for i in range(len(labels)):
        if labels[i] == 0:
            target[0] = 1
        if labels[i] == 1:
            target[1] = 1
        if labels[i] == 4:
            target[2] = 1
        if labels[i] == 5:
            target[3] = 1
        if labels[i] == 8:
            target[4] = 1
    return target

# %%
# Helper function transfer path to tensorflow images
def path_to_tensor(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(tensors)

# %%
# Helper function to print loss function and accuracy history
def history(model):
    plt.figure(figsize = (15, 5) )

    plt.subplot(121)
    plt.plot(model.history['loss'], color='blue', label='train')
    plt.plot(model.history['val_loss'], color='red', label='valid')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss Function')

    plt.subplot(122)
    plt.plot(model.history['binary_accuracy'], color = 'blue', label='train')
    plt.plot(model.history['val_binary_accuracy'], color='red', label='valid')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')

# %%
# Helper function to calculate results
def true_pos(y_true, y_pred):
    return np.sum(y_true * y_pred)


def false_pos(y_true, y_pred):
    return np.sum(y_true * (1. - y_pred))


def false_neg(y_true, y_pred):
    return np.sum((1. - y_true) * y_pred)


def precision(y_true, y_pred):
    return true_pos(y_true, y_pred) / (true_pos(y_true, y_pred) + false_pos(y_true, y_pred))


def recall(y_true, y_pred):
    return true_pos(y_true, y_pred) / (true_pos(y_true, y_pred) + false_neg(y_true, y_pred))


def f1_score(y_true, y_pred):
    return 2. / (1. / recall(y_true, y_pred) + 1. / precision(y_true, y_pred))

# %% [markdown]
# ### Preprocess

# %%
# Business id to labels
biz2labels = pd.read_csv('Data/train.csv', header = 0, names = ['business','labels']).fillna('')

# Photo id to business id for the training dataset
photo2biz_train = pd.read_csv('Data/train_photo_to_biz_ids.csv', header = 0, names = ['photo','business'])

# Get list of photo id 
photo_ids = np.array(photo2biz_train['photo'])

print('There are %d training images' % len(photo_ids))
# Out:
# There are 234842 training images

# %%
biz2labels['labels'] = biz2labels['labels'].apply(lambda x: tuple(sorted(int(t) for t in x.split())))
biz2labels.set_index('business', inplace=True)
biz2labels.head(n=10)
# Out:
#                          labels
# business
# 1000      (1, 2, 3, 4, 5, 6, 7)
# 1001               (0, 1, 6, 8)
# 100          (1, 2, 4, 5, 6, 7)
# 1006            (1, 2, 4, 5, 6)
# 1010                  (0, 6, 8)
# 101          (1, 2, 3, 4, 5, 6)
# 1011               (2, 3, 5, 6)
# 1012            (1, 2, 3, 5, 6)
# 1014            (1, 2, 4, 5, 6)
# 1015               (1, 5, 6, 7)

# %%
biz2labels['new_label'] = [[0]]*len(biz2labels)
for i in biz2labels.index:
    biz2labels.at[i, 'new_label'] = tuple(i for i in biz2labels.loc[i]['labels'] if i in [0,1,4,5,8])
biz2labels.head(n=10)
# Out:
#                          labels  new_label
# business
# 1000      (1, 2, 3, 4, 5, 6, 7)  (1, 4, 5)
# 1001               (0, 1, 6, 8)  (0, 1, 8)
# 100          (1, 2, 4, 5, 6, 7)  (1, 4, 5)
# 1006            (1, 2, 4, 5, 6)  (1, 4, 5)
# 1010                  (0, 6, 8)     (0, 8)
# 101          (1, 2, 3, 4, 5, 6)  (1, 4, 5)
# 1011               (2, 3, 5, 6)       (5,)
# 1012            (1, 2, 3, 5, 6)     (1, 5)
# 1014            (1, 2, 4, 5, 6)  (1, 4, 5)
# 1015               (1, 5, 6, 7)     (1, 5)

# %%
photo_targets = np.vstack(biz2labels.loc[photo2biz_train['business']]['new_label'].apply(encode_new_label))
print('Number of rows: %d - Number of columns: %d' % (photo_targets.shape[0], photo_targets.shape[1]))
# Out:
# Number of rows: 234842 - Number of columns: 5

# %%
from sklearn.model_selection import train_test_split

train_files, test_files, train_targets, test_targets = train_test_split(photo_ids,
                                                                        photo_targets,
                                                                        test_size=0.25,
                                                                        random_state=7)

valid_files, valid_targets = (test_files[:int(len(test_files)/2)], test_targets[:int(len(test_files)/2)])
test_files, test_targets = (test_files[int(len(test_files)/2):], test_targets[int(len(test_files)/2):])

print('There are %d images in the training dataset' % len(train_files))
print('There are %d images in the validation dataset' % len(valid_files))
print('There are %d images in the test dataset' % len(test_files))
# Out:
# There are 176131 images in the training dataset
# There are 29355 images in the validation dataset
# There are 29356 images in the test dataset

# %%
# Load Pictures
train_files = np.array(['Data/train_photos/' + str(i) + '.jpg' for i in train_files])
valid_files = np.array(['Data/train_photos/' + str(i) + '.jpg' for i in valid_files])
test_files = np.array(['Data/train_photos/' + str(i) + '.jpg' for i in test_files])

print('There are %d images in the training dataset' % len(train_files))
print('There are %d images in the validation dataset' % len(valid_files))
print('There are %d images in the test dataset' % len(test_files))
# Out:
# There are 176131 images in the training dataset
# There are 29355 images in the validation dataset
# There are 29356 images in the test dataset

# %%
# Number of pictures to process for each dataset
nb_train, nb_valid, nb_test = (20000,2000,2000)

# %% [markdown]
# ### ResNet50

# %%
train_tensors = preprocess_input(paths_to_tensor(train_files[:nb_train]))
valid_tensors = preprocess_input(paths_to_tensor(valid_files[:nb_valid]))
test_tensors = preprocess_input(paths_to_tensor(test_files[:nb_test]))
# Out:
# 100%|████████████████████████████████████| 20000/20000 [00:39<00:00, 500.99it/s]
# 100%|██████████████████████████████████████| 2000/2000 [00:04<00:00, 445.24it/s]
# 100%|██████████████████████████████████████| 2000/2000 [00:04<00:00, 483.89it/s]

# %%
model = ResNet50(include_top=False)
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
#  pool1_pool (MaxPooling2D)      (None, None, None,   0           ['pool1_pad[0][0]']
#                                 64)
#
#  conv2_block1_1_conv (Conv2D)   (None, None, None,   4160        ['pool1_pool[0][0]']
#                                 64)
#
#  conv2_block1_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_1_relu (Activatio  (None, None, None,   0          ['conv2_block1_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block1_1_relu[0][0]']
#                                 64)
#
#  conv2_block1_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_2_relu (Activatio  (None, None, None,   0          ['conv2_block1_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_0_conv (Conv2D)   (None, None, None,   16640       ['pool1_pool[0][0]']
#                                 256)
#
#  conv2_block1_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block1_2_relu[0][0]']
#                                 256)
#
#  conv2_block1_0_bn (BatchNormal  (None, None, None,   1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       256)
#
#  conv2_block1_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block1_add (Add)         (None, None, None,   0           ['conv2_block1_0_bn[0][0]',
#                                 256)                              'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, None, None,   0           ['conv2_block1_add[0][0]']
#                                 256)
#
#  conv2_block2_1_conv (Conv2D)   (None, None, None,   16448       ['conv2_block1_out[0][0]']
#                                 64)
#
#  conv2_block2_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_1_relu (Activatio  (None, None, None,   0          ['conv2_block2_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block2_1_relu[0][0]']
#                                 64)
#
#  conv2_block2_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_2_relu (Activatio  (None, None, None,   0          ['conv2_block2_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block2_2_relu[0][0]']
#                                 256)
#
#  conv2_block2_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block2_add (Add)         (None, None, None,   0           ['conv2_block1_out[0][0]',
#                                 256)                              'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, None, None,   0           ['conv2_block2_add[0][0]']
#                                 256)
#
#  conv2_block3_1_conv (Conv2D)   (None, None, None,   16448       ['conv2_block2_out[0][0]']
#                                 64)
#
#  conv2_block3_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_1_relu (Activatio  (None, None, None,   0          ['conv2_block3_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block3_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block3_1_relu[0][0]']
#                                 64)
#
#  conv2_block3_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_2_relu (Activatio  (None, None, None,   0          ['conv2_block3_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block3_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block3_2_relu[0][0]']
#                                 256)
#
#  conv2_block3_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block3_add (Add)         (None, None, None,   0           ['conv2_block2_out[0][0]',
#                                 256)                              'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, None, None,   0           ['conv2_block3_add[0][0]']
#                                 256)
#
#  conv3_block1_1_conv (Conv2D)   (None, None, None,   32896       ['conv2_block3_out[0][0]']
#                                 128)
#
#  conv3_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_1_relu (Activatio  (None, None, None,   0          ['conv3_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block1_1_relu[0][0]']
#                                 128)
#
#  conv3_block1_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_2_relu (Activatio  (None, None, None,   0          ['conv3_block1_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_0_conv (Conv2D)   (None, None, None,   131584      ['conv2_block3_out[0][0]']
#                                 512)
#
#  conv3_block1_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block1_2_relu[0][0]']
#                                 512)
#
#  conv3_block1_0_bn (BatchNormal  (None, None, None,   2048       ['conv3_block1_0_conv[0][0]']
#  ization)                       512)
#
#  conv3_block1_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block1_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block1_add (Add)         (None, None, None,   0           ['conv3_block1_0_bn[0][0]',
#                                 512)                              'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, None, None,   0           ['conv3_block1_add[0][0]']
#                                 512)
#
#  conv3_block2_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block1_out[0][0]']
#                                 128)
#
#  conv3_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_1_relu (Activatio  (None, None, None,   0          ['conv3_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block2_1_relu[0][0]']
#                                 128)
#
#  conv3_block2_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_2_relu (Activatio  (None, None, None,   0          ['conv3_block2_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block2_2_relu[0][0]']
#                                 512)
#
#  conv3_block2_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block2_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block2_add (Add)         (None, None, None,   0           ['conv3_block1_out[0][0]',
#                                 512)                              'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, None, None,   0           ['conv3_block2_add[0][0]']
#                                 512)
#
#  conv3_block3_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block2_out[0][0]']
#                                 128)
#
#  conv3_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_1_relu (Activatio  (None, None, None,   0          ['conv3_block3_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block3_1_relu[0][0]']
#                                 128)
#
#  conv3_block3_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_2_relu (Activatio  (None, None, None,   0          ['conv3_block3_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block3_2_relu[0][0]']
#                                 512)
#
#  conv3_block3_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block3_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block3_add (Add)         (None, None, None,   0           ['conv3_block2_out[0][0]',
#                                 512)                              'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, None, None,   0           ['conv3_block3_add[0][0]']
#                                 512)
#
#  conv3_block4_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block3_out[0][0]']
#                                 128)
#
#  conv3_block4_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_1_relu (Activatio  (None, None, None,   0          ['conv3_block4_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block4_1_relu[0][0]']
#                                 128)
#
#  conv3_block4_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_2_relu (Activatio  (None, None, None,   0          ['conv3_block4_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block4_2_relu[0][0]']
#                                 512)
#
#  conv3_block4_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block4_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block4_add (Add)         (None, None, None,   0           ['conv3_block3_out[0][0]',
#                                 512)                              'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, None, None,   0           ['conv3_block4_add[0][0]']
#                                 512)
#
#  conv4_block1_1_conv (Conv2D)   (None, None, None,   131328      ['conv3_block4_out[0][0]']
#                                 256)
#  conv4_block1_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_1_relu (Activatio  (None, None, None,   0          ['conv4_block1_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block1_1_relu[0][0]']
#                                 256)
#
#  conv4_block1_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_2_relu (Activatio  (None, None, None,   0          ['conv4_block1_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_0_conv (Conv2D)   (None, None, None,   525312      ['conv3_block4_out[0][0]']
#                                 1024)
#
#  conv4_block1_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block1_2_relu[0][0]']
#                                 1024)
#
#  conv4_block1_0_bn (BatchNormal  (None, None, None,   4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block1_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block1_add (Add)         (None, None, None,   0           ['conv4_block1_0_bn[0][0]',
#                                 1024)                             'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, None, None,   0           ['conv4_block1_add[0][0]']
#                                 1024)
#
#  conv4_block2_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block1_out[0][0]']
#                                 256)
#
#  conv4_block2_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_1_relu (Activatio  (None, None, None,   0          ['conv4_block2_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block2_1_relu[0][0]']
#                                 256)
#
#  conv4_block2_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_2_relu (Activatio  (None, None, None,   0          ['conv4_block2_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block2_2_relu[0][0]']
#                                 1024)
#
#  conv4_block2_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block2_add (Add)         (None, None, None,   0           ['conv4_block1_out[0][0]',
#                                 1024)                             'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, None, None,   0           ['conv4_block2_add[0][0]']
#                                 1024)
#
#  conv4_block3_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block2_out[0][0]']
#                                 256)
#
#  conv4_block3_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_1_relu (Activatio  (None, None, None,   0          ['conv4_block3_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block3_1_relu[0][0]']
#                                 256)
#
#  conv4_block3_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_2_relu (Activatio  (None, None, None,   0          ['conv4_block3_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block3_2_relu[0][0]']
#                                 1024)
#
#  conv4_block3_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block3_add (Add)         (None, None, None,   0           ['conv4_block2_out[0][0]',
#                                 1024)                             'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, None, None,   0           ['conv4_block3_add[0][0]']
#                                 1024)
#
#  conv4_block4_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block3_out[0][0]']
#                                 256)
#
#  conv4_block4_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_1_relu (Activatio  (None, None, None,   0          ['conv4_block4_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block4_1_relu[0][0]']
#                                 256)
#
#  conv4_block4_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_2_relu (Activatio  (None, None, None,   0          ['conv4_block4_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block4_2_relu[0][0]']
#                                 1024)
#
#  conv4_block4_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block4_add (Add)         (None, None, None,   0           ['conv4_block3_out[0][0]',
#                                 1024)                             'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, None, None,   0           ['conv4_block4_add[0][0]']
#                                 1024)
#
#  conv4_block5_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block4_out[0][0]']
#                                 256)
#
#  conv4_block5_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_1_relu (Activatio  (None, None, None,   0          ['conv4_block5_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block5_1_relu[0][0]']
#                                 256)
#
#  conv4_block5_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_2_relu (Activatio  (None, None, None,   0          ['conv4_block5_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block5_2_relu[0][0]']
#                                 1024)
#
#  conv4_block5_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block5_add (Add)         (None, None, None,   0           ['conv4_block4_out[0][0]',
#                                 1024)                             'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, None, None,   0           ['conv4_block5_add[0][0]']
#                                 1024)
#
#  conv4_block6_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block5_out[0][0]']
#                                 256)
#
#  conv4_block6_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_1_relu (Activatio  (None, None, None,   0          ['conv4_block6_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block6_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block6_1_relu[0][0]']
#                                 256)
#
#  conv4_block6_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_2_relu (Activatio  (None, None, None,   0          ['conv4_block6_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block6_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block6_2_relu[0][0]']
#                                 1024)
#
#  conv4_block6_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block6_add (Add)         (None, None, None,   0           ['conv4_block5_out[0][0]',
#                                 1024)                             'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, None, None,   0           ['conv4_block6_add[0][0]']
#                                 1024)
#
#  conv5_block1_1_conv (Conv2D)   (None, None, None,   524800      ['conv4_block6_out[0][0]']
#                                 512)
#
#  conv5_block1_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_1_relu (Activatio  (None, None, None,   0          ['conv5_block1_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block1_1_relu[0][0]']
#                                 512)
#
#  conv5_block1_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_2_relu (Activatio  (None, None, None,   0          ['conv5_block1_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_0_conv (Conv2D)   (None, None, None,   2099200     ['conv4_block6_out[0][0]']
#                                 2048)
#
#  conv5_block1_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block1_2_relu[0][0]']
#                                 2048)
#
#  conv5_block1_0_bn (BatchNormal  (None, None, None,   8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block1_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block1_add (Add)         (None, None, None,   0           ['conv5_block1_0_bn[0][0]',
#                                 2048)                             'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, None, None,   0           ['conv5_block1_add[0][0]']
#                                 2048)
#
#  conv5_block2_1_conv (Conv2D)   (None, None, None,   1049088     ['conv5_block1_out[0][0]']
#                                 512)
#
#  conv5_block2_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_1_relu (Activatio  (None, None, None,   0          ['conv5_block2_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block2_1_relu[0][0]']
#                                 512)
#
#  conv5_block2_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_2_relu (Activatio  (None, None, None,   0          ['conv5_block2_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block2_2_relu[0][0]']
#                                 2048)
#
#  conv5_block2_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block2_add (Add)         (None, None, None,   0           ['conv5_block1_out[0][0]',
#                                 2048)                             'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, None, None,   0           ['conv5_block2_add[0][0]']
#                                 2048)
#  conv5_block3_1_conv (Conv2D)   (None, None, None,   1049088     ['conv5_block2_out[0][0]']
#                                 512)
#
#  conv5_block3_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_1_relu (Activatio  (None, None, None,   0          ['conv5_block3_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block3_1_relu[0][0]']
#                                 512)
#
#  conv5_block3_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_2_relu (Activatio  (None, None, None,   0          ['conv5_block3_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block3_2_relu[0][0]']
#                                 2048)
#
#  conv5_block3_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block3_add (Add)         (None, None, None,   0           ['conv5_block2_out[0][0]',
#                                 2048)                             'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, None, None,   0           ['conv5_block3_add[0][0]']
#                                 2048)
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
train_resnet50 = model.predict(train_tensors)
valid_resnet50 = model.predict(valid_tensors)
test_resnet50  = model.predict(test_tensors)
# Out:
# 2022-05-31 19:11:51.002201: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
np.savez('yelp_resnet50_5.npz', 
         train_features=train_resnet50, train_targets=train_targets[:nb_train],
         valid_features=valid_resnet50, valid_targets=valid_targets[:nb_valid],
         test_features=test_resnet50, test_targets=test_targets[:nb_test])

# %%
bottleneck_features = np.load('yelp_resnet50_5.npz')
train_resnet50 = bottleneck_features['train_features']
valid_resnet50 = bottleneck_features['valid_features']
test_resnet50 = bottleneck_features['test_features']

train_targets = bottleneck_features['train_targets']
valid_targets = bottleneck_features['valid_targets']
test_targets = bottleneck_features['test_targets']

# %%
# Create Model
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D, MaxPooling2D 
from keras.layers import Conv2D, Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.regularizers import l2

resnet50 = Sequential()
resnet50.add(GlobalAveragePooling2D(input_shape=train_resnet50.shape[1:]))

resnet50.add(Dense(1024, activation='relu', kernel_regularizer=l2(1e-4)))
resnet50.add(BatchNormalization())
resnet50.add(Dropout(0.3))

resnet50.add(Dense(512, activation='relu', kernel_regularizer=l2(1e-4)))
resnet50.add(BatchNormalization())
resnet50.add(Dropout(0.3))

resnet50.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
resnet50.add(BatchNormalization())

resnet50.add(Dense(5, activation='sigmoid'))

resnet50.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 2,762,757
# Trainable params: 2,759,173
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD

sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
resnet50.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['binary_accuracy'])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

checkpointer = ModelCheckpoint(filepath='weights_compare_resnet50_5.hdf5', save_best_only=True)
checkimprovement = EarlyStopping(monitor='val_loss', min_delta=0, patience=20)

history_resnet50 = resnet50.fit(train_resnet50, train_targets, 
                                validation_data=(valid_resnet50,valid_targets), 
                                epochs=1000, batch_size=64,
                                callbacks=[checkpointer,checkimprovement]
                               )
# Out:
# Epoch 1/1000
# 313/313 [==============================] - 5s 15ms/step - loss: 1.0816 - binary_accuracy: 0.5268 - val_loss: 0.9374 - val_binary_accuracy: 0.5784
# Epoch 2/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 1.0167 - binary_accuracy: 0.5681 - val_loss: 0.9127 - val_binary_accuracy: 0.6136
# Epoch 3/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9785 - binary_accuracy: 0.5945 - val_loss: 0.8903 - val_binary_accuracy: 0.6406
# Epoch 4/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9521 - binary_accuracy: 0.6161 - val_loss: 0.8734 - val_binary_accuracy: 0.6563
# Epoch 5/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.9314 - binary_accuracy: 0.6309 - val_loss: 0.8591 - val_binary_accuracy: 0.6694
# Epoch 6/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9155 - binary_accuracy: 0.6402 - val_loss: 0.8496 - val_binary_accuracy: 0.6764
# Epoch 7/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9011 - binary_accuracy: 0.6526 - val_loss: 0.8406 - val_binary_accuracy: 0.6851
# Epoch 8/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8941 - binary_accuracy: 0.6574 - val_loss: 0.8342 - val_binary_accuracy: 0.6919
# Epoch 9/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8785 - binary_accuracy: 0.6700 - val_loss: 0.8296 - val_binary_accuracy: 0.6963
# Epoch 10/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8707 - binary_accuracy: 0.6733 - val_loss: 0.8237 - val_binary_accuracy: 0.7005
# Epoch 11/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8630 - binary_accuracy: 0.6780 - val_loss: 0.8179 - val_binary_accuracy: 0.7056
# Epoch 12/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8535 - binary_accuracy: 0.6864 - val_loss: 0.8125 - val_binary_accuracy: 0.7108
# Epoch 13/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.8483 - binary_accuracy: 0.6905 - val_loss: 0.8081 - val_binary_accuracy: 0.7144
# Epoch 14/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8390 - binary_accuracy: 0.6940 - val_loss: 0.8048 - val_binary_accuracy: 0.7168
# Epoch 15/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8344 - binary_accuracy: 0.6983 - val_loss: 0.7995 - val_binary_accuracy: 0.7198
# Epoch 16/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8271 - binary_accuracy: 0.7029 - val_loss: 0.7965 - val_binary_accuracy: 0.7220
# Epoch 17/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8225 - binary_accuracy: 0.7062 - val_loss: 0.7927 - val_binary_accuracy: 0.7256
# Epoch 18/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8171 - binary_accuracy: 0.7094 - val_loss: 0.7901 - val_binary_accuracy: 0.7270
# Epoch 19/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8139 - binary_accuracy: 0.7100 - val_loss: 0.7871 - val_binary_accuracy: 0.7296
# Epoch 20/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8096 - binary_accuracy: 0.7140 - val_loss: 0.7837 - val_binary_accuracy: 0.7306
# Epoch 21/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8050 - binary_accuracy: 0.7170 - val_loss: 0.7808 - val_binary_accuracy: 0.7330
# Epoch 22/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7993 - binary_accuracy: 0.7210 - val_loss: 0.7783 - val_binary_accuracy: 0.7355
# Epoch 23/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7958 - binary_accuracy: 0.7246 - val_loss: 0.7763 - val_binary_accuracy: 0.7367
# Epoch 24/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7931 - binary_accuracy: 0.7241 - val_loss: 0.7743 - val_binary_accuracy: 0.7389
# Epoch 25/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7862 - binary_accuracy: 0.7292 - val_loss: 0.7718 - val_binary_accuracy: 0.7400
# Epoch 26/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7842 - binary_accuracy: 0.7300 - val_loss: 0.7690 - val_binary_accuracy: 0.7407
# Epoch 27/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7829 - binary_accuracy: 0.7309 - val_loss: 0.7683 - val_binary_accuracy: 0.7421
# Epoch 28/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7758 - binary_accuracy: 0.7359 - val_loss: 0.7669 - val_binary_accuracy: 0.7426
# Epoch 29/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7745 - binary_accuracy: 0.7362 - val_loss: 0.7654 - val_binary_accuracy: 0.7441
# Epoch 30/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7732 - binary_accuracy: 0.7372 - val_loss: 0.7621 - val_binary_accuracy: 0.7453
# Epoch 31/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7678 - binary_accuracy: 0.7411 - val_loss: 0.7611 - val_binary_accuracy: 0.7463
# Epoch 32/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7686 - binary_accuracy: 0.7406 - val_loss: 0.7600 - val_binary_accuracy: 0.7474
# Epoch 33/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7643 - binary_accuracy: 0.7432 - val_loss: 0.7579 - val_binary_accuracy: 0.7489
# Epoch 34/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7598 - binary_accuracy: 0.7454 - val_loss: 0.7578 - val_binary_accuracy: 0.7484
# Epoch 35/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7597 - binary_accuracy: 0.7463 - val_loss: 0.7556 - val_binary_accuracy: 0.7496
# Epoch 36/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7561 - binary_accuracy: 0.7474 - val_loss: 0.7541 - val_binary_accuracy: 0.7505
# Epoch 37/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7552 - binary_accuracy: 0.7475 - val_loss: 0.7523 - val_binary_accuracy: 0.7523
# Epoch 38/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7520 - binary_accuracy: 0.7495 - val_loss: 0.7519 - val_binary_accuracy: 0.7521
# Epoch 39/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7504 - binary_accuracy: 0.7515 - val_loss: 0.7506 - val_binary_accuracy: 0.7534
# Epoch 40/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7494 - binary_accuracy: 0.7502 - val_loss: 0.7491 - val_binary_accuracy: 0.7540
# Epoch 41/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7462 - binary_accuracy: 0.7544 - val_loss: 0.7483 - val_binary_accuracy: 0.7546
# Epoch 42/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7461 - binary_accuracy: 0.7549 - val_loss: 0.7474 - val_binary_accuracy: 0.7546
# Epoch 43/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7458 - binary_accuracy: 0.7543 - val_loss: 0.7460 - val_binary_accuracy: 0.7544
# Epoch 44/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7399 - binary_accuracy: 0.7592 - val_loss: 0.7455 - val_binary_accuracy: 0.7537
# Epoch 45/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7389 - binary_accuracy: 0.7578 - val_loss: 0.7446 - val_binary_accuracy: 0.7548
# Epoch 46/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.7388 - binary_accuracy: 0.7583 - val_loss: 0.7441 - val_binary_accuracy: 0.7555
# Epoch 47/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7377 - binary_accuracy: 0.7587 - val_loss: 0.7428 - val_binary_accuracy: 0.7555
# Epoch 48/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7333 - binary_accuracy: 0.7613 - val_loss: 0.7422 - val_binary_accuracy: 0.7564
# Epoch 49/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7336 - binary_accuracy: 0.7610 - val_loss: 0.7410 - val_binary_accuracy: 0.7566
# Epoch 50/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.7323 - binary_accuracy: 0.7618 - val_loss: 0.7401 - val_binary_accuracy: 0.7576
# Epoch 51/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.7308 - binary_accuracy: 0.7618 - val_loss: 0.7396 - val_binary_accuracy: 0.7581
# Epoch 52/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.7293 - binary_accuracy: 0.7639 - val_loss: 0.7386 - val_binary_accuracy: 0.7585
# Epoch 53/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7280 - binary_accuracy: 0.7646 - val_loss: 0.7382 - val_binary_accuracy: 0.7595
# Epoch 54/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7257 - binary_accuracy: 0.7663 - val_loss: 0.7372 - val_binary_accuracy: 0.7607
# Epoch 55/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7258 - binary_accuracy: 0.7647 - val_loss: 0.7367 - val_binary_accuracy: 0.7612
# Epoch 56/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7219 - binary_accuracy: 0.7664 - val_loss: 0.7363 - val_binary_accuracy: 0.7609
# Epoch 57/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7199 - binary_accuracy: 0.7697 - val_loss: 0.7359 - val_binary_accuracy: 0.7620
# Epoch 58/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7218 - binary_accuracy: 0.7670 - val_loss: 0.7353 - val_binary_accuracy: 0.7614
# Epoch 59/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7176 - binary_accuracy: 0.7694 - val_loss: 0.7345 - val_binary_accuracy: 0.7623
# Epoch 60/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7175 - binary_accuracy: 0.7698 - val_loss: 0.7341 - val_binary_accuracy: 0.7629
# Epoch 61/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7169 - binary_accuracy: 0.7706 - val_loss: 0.7339 - val_binary_accuracy: 0.7617
# Epoch 62/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7151 - binary_accuracy: 0.7714 - val_loss: 0.7334 - val_binary_accuracy: 0.7639
# Epoch 63/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7154 - binary_accuracy: 0.7718 - val_loss: 0.7330 - val_binary_accuracy: 0.7635
# Epoch 64/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7115 - binary_accuracy: 0.7741 - val_loss: 0.7322 - val_binary_accuracy: 0.7641
# Epoch 65/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7124 - binary_accuracy: 0.7716 - val_loss: 0.7319 - val_binary_accuracy: 0.7641
# Epoch 66/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7101 - binary_accuracy: 0.7744 - val_loss: 0.7315 - val_binary_accuracy: 0.7643
# Epoch 67/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7096 - binary_accuracy: 0.7752 - val_loss: 0.7311 - val_binary_accuracy: 0.7653
# Epoch 68/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7105 - binary_accuracy: 0.7741 - val_loss: 0.7300 - val_binary_accuracy: 0.7667
# Epoch 69/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7092 - binary_accuracy: 0.7748 - val_loss: 0.7299 - val_binary_accuracy: 0.7668
# Epoch 70/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7097 - binary_accuracy: 0.7757 - val_loss: 0.7299 - val_binary_accuracy: 0.7666
# Epoch 71/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7053 - binary_accuracy: 0.7773 - val_loss: 0.7290 - val_binary_accuracy: 0.7673
# Epoch 72/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7056 - binary_accuracy: 0.7762 - val_loss: 0.7285 - val_binary_accuracy: 0.7671
# Epoch 73/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7017 - binary_accuracy: 0.7801 - val_loss: 0.7283 - val_binary_accuracy: 0.7687
# Epoch 74/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7043 - binary_accuracy: 0.7778 - val_loss: 0.7279 - val_binary_accuracy: 0.7690
# Epoch 75/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7014 - binary_accuracy: 0.7791 - val_loss: 0.7275 - val_binary_accuracy: 0.7693
# Epoch 76/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7006 - binary_accuracy: 0.7803 - val_loss: 0.7271 - val_binary_accuracy: 0.7682
# Epoch 77/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6989 - binary_accuracy: 0.7805 - val_loss: 0.7270 - val_binary_accuracy: 0.7686
# Epoch 78/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6986 - binary_accuracy: 0.7823 - val_loss: 0.7266 - val_binary_accuracy: 0.7687
# Epoch 79/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6999 - binary_accuracy: 0.7800 - val_loss: 0.7259 - val_binary_accuracy: 0.7686
# Epoch 80/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6990 - binary_accuracy: 0.7795 - val_loss: 0.7266 - val_binary_accuracy: 0.7697
# Epoch 81/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6980 - binary_accuracy: 0.7819 - val_loss: 0.7255 - val_binary_accuracy: 0.7678
# Epoch 82/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6960 - binary_accuracy: 0.7824 - val_loss: 0.7255 - val_binary_accuracy: 0.7682
# Epoch 83/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6945 - binary_accuracy: 0.7833 - val_loss: 0.7249 - val_binary_accuracy: 0.7695
# Epoch 84/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6951 - binary_accuracy: 0.7828 - val_loss: 0.7246 - val_binary_accuracy: 0.7701
# Epoch 85/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6928 - binary_accuracy: 0.7850 - val_loss: 0.7244 - val_binary_accuracy: 0.7693
# Epoch 86/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6932 - binary_accuracy: 0.7835 - val_loss: 0.7238 - val_binary_accuracy: 0.7686
# Epoch 87/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6892 - binary_accuracy: 0.7859 - val_loss: 0.7237 - val_binary_accuracy: 0.7695
# Epoch 88/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6946 - binary_accuracy: 0.7834 - val_loss: 0.7235 - val_binary_accuracy: 0.7693
# Epoch 89/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6883 - binary_accuracy: 0.7861 - val_loss: 0.7233 - val_binary_accuracy: 0.7695
# Epoch 90/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6904 - binary_accuracy: 0.7844 - val_loss: 0.7234 - val_binary_accuracy: 0.7694
# Epoch 91/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6878 - binary_accuracy: 0.7880 - val_loss: 0.7229 - val_binary_accuracy: 0.7701
# Epoch 92/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6869 - binary_accuracy: 0.7868 - val_loss: 0.7229 - val_binary_accuracy: 0.7699
# Epoch 93/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6864 - binary_accuracy: 0.7872 - val_loss: 0.7226 - val_binary_accuracy: 0.7705
# Epoch 94/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6879 - binary_accuracy: 0.7857 - val_loss: 0.7223 - val_binary_accuracy: 0.7700
# Epoch 95/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6844 - binary_accuracy: 0.7877 - val_loss: 0.7220 - val_binary_accuracy: 0.7713
# Epoch 96/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6841 - binary_accuracy: 0.7883 - val_loss: 0.7219 - val_binary_accuracy: 0.7709
# Epoch 97/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6841 - binary_accuracy: 0.7886 - val_loss: 0.7217 - val_binary_accuracy: 0.7722
# Epoch 98/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6832 - binary_accuracy: 0.7898 - val_loss: 0.7216 - val_binary_accuracy: 0.7707
# Epoch 99/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6807 - binary_accuracy: 0.7899 - val_loss: 0.7213 - val_binary_accuracy: 0.7715
# Epoch 100/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6809 - binary_accuracy: 0.7895 - val_loss: 0.7210 - val_binary_accuracy: 0.7720
# Epoch 101/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6802 - binary_accuracy: 0.7904 - val_loss: 0.7208 - val_binary_accuracy: 0.7714
# Epoch 102/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6810 - binary_accuracy: 0.7900 - val_loss: 0.7204 - val_binary_accuracy: 0.7723
# Epoch 103/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6799 - binary_accuracy: 0.7912 - val_loss: 0.7203 - val_binary_accuracy: 0.7724
# Epoch 104/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6785 - binary_accuracy: 0.7916 - val_loss: 0.7201 - val_binary_accuracy: 0.7732
# Epoch 105/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6780 - binary_accuracy: 0.7926 - val_loss: 0.7200 - val_binary_accuracy: 0.7726
# Epoch 106/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6765 - binary_accuracy: 0.7931 - val_loss: 0.7195 - val_binary_accuracy: 0.7724
# Epoch 107/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6786 - binary_accuracy: 0.7922 - val_loss: 0.7192 - val_binary_accuracy: 0.7717
# Epoch 108/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6756 - binary_accuracy: 0.7933 - val_loss: 0.7192 - val_binary_accuracy: 0.7726
# Epoch 109/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6755 - binary_accuracy: 0.7935 - val_loss: 0.7190 - val_binary_accuracy: 0.7721
# Epoch 110/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6749 - binary_accuracy: 0.7934 - val_loss: 0.7188 - val_binary_accuracy: 0.7723
# Epoch 111/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6736 - binary_accuracy: 0.7950 - val_loss: 0.7190 - val_binary_accuracy: 0.7727
# Epoch 112/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6729 - binary_accuracy: 0.7946 - val_loss: 0.7188 - val_binary_accuracy: 0.7728
# Epoch 113/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6719 - binary_accuracy: 0.7964 - val_loss: 0.7186 - val_binary_accuracy: 0.7725
# Epoch 114/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6705 - binary_accuracy: 0.7965 - val_loss: 0.7183 - val_binary_accuracy: 0.7737
# Epoch 115/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6696 - binary_accuracy: 0.7964 - val_loss: 0.7178 - val_binary_accuracy: 0.7728
# Epoch 116/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6682 - binary_accuracy: 0.7981 - val_loss: 0.7180 - val_binary_accuracy: 0.7723
# Epoch 117/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6706 - binary_accuracy: 0.7945 - val_loss: 0.7176 - val_binary_accuracy: 0.7738
# Epoch 118/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6684 - binary_accuracy: 0.7972 - val_loss: 0.7177 - val_binary_accuracy: 0.7739
# Epoch 119/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6680 - binary_accuracy: 0.7968 - val_loss: 0.7175 - val_binary_accuracy: 0.7732
# Epoch 120/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6682 - binary_accuracy: 0.7987 - val_loss: 0.7171 - val_binary_accuracy: 0.7738
# Epoch 121/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6662 - binary_accuracy: 0.7979 - val_loss: 0.7171 - val_binary_accuracy: 0.7741
# Epoch 122/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6661 - binary_accuracy: 0.7992 - val_loss: 0.7171 - val_binary_accuracy: 0.7741
# Epoch 123/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6668 - binary_accuracy: 0.7974 - val_loss: 0.7170 - val_binary_accuracy: 0.7744
# Epoch 124/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6633 - binary_accuracy: 0.8006 - val_loss: 0.7173 - val_binary_accuracy: 0.7740
# Epoch 125/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6660 - binary_accuracy: 0.7985 - val_loss: 0.7169 - val_binary_accuracy: 0.7745
# Epoch 126/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6624 - binary_accuracy: 0.8014 - val_loss: 0.7169 - val_binary_accuracy: 0.7737
# Epoch 127/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6625 - binary_accuracy: 0.7997 - val_loss: 0.7165 - val_binary_accuracy: 0.7746
# Epoch 128/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6600 - binary_accuracy: 0.8019 - val_loss: 0.7169 - val_binary_accuracy: 0.7742
# Epoch 129/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6614 - binary_accuracy: 0.8004 - val_loss: 0.7169 - val_binary_accuracy: 0.7741
# Epoch 130/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6609 - binary_accuracy: 0.8003 - val_loss: 0.7165 - val_binary_accuracy: 0.7739
# Epoch 131/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6591 - binary_accuracy: 0.8041 - val_loss: 0.7168 - val_binary_accuracy: 0.7762
# Epoch 132/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6594 - binary_accuracy: 0.8021 - val_loss: 0.7165 - val_binary_accuracy: 0.7758
# Epoch 133/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6604 - binary_accuracy: 0.8023 - val_loss: 0.7163 - val_binary_accuracy: 0.7744
# Epoch 134/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6603 - binary_accuracy: 0.8027 - val_loss: 0.7162 - val_binary_accuracy: 0.7751
# Epoch 135/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6574 - binary_accuracy: 0.8033 - val_loss: 0.7159 - val_binary_accuracy: 0.7747
# Epoch 136/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6557 - binary_accuracy: 0.8051 - val_loss: 0.7161 - val_binary_accuracy: 0.7749
# Epoch 137/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6567 - binary_accuracy: 0.8039 - val_loss: 0.7158 - val_binary_accuracy: 0.7743
# Epoch 138/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6537 - binary_accuracy: 0.8061 - val_loss: 0.7158 - val_binary_accuracy: 0.7749
# Epoch 139/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6531 - binary_accuracy: 0.8072 - val_loss: 0.7162 - val_binary_accuracy: 0.7745
# Epoch 140/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6544 - binary_accuracy: 0.8054 - val_loss: 0.7159 - val_binary_accuracy: 0.7746
# Epoch 141/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6544 - binary_accuracy: 0.8042 - val_loss: 0.7158 - val_binary_accuracy: 0.7741
# Epoch 142/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6516 - binary_accuracy: 0.8069 - val_loss: 0.7155 - val_binary_accuracy: 0.7743
# Epoch 143/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6525 - binary_accuracy: 0.8060 - val_loss: 0.7156 - val_binary_accuracy: 0.7739
# Epoch 144/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6515 - binary_accuracy: 0.8064 - val_loss: 0.7158 - val_binary_accuracy: 0.7750
# Epoch 145/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6514 - binary_accuracy: 0.8071 - val_loss: 0.7156 - val_binary_accuracy: 0.7747
# Epoch 146/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6513 - binary_accuracy: 0.8074 - val_loss: 0.7152 - val_binary_accuracy: 0.7756
# Epoch 147/1000
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6486 - binary_accuracy: 0.8085 - val_loss: 0.7153 - val_binary_accuracy: 0.7745
# Epoch 148/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6479 - binary_accuracy: 0.8093 - val_loss: 0.7156 - val_binary_accuracy: 0.7748
# Epoch 149/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6485 - binary_accuracy: 0.8082 - val_loss: 0.7152 - val_binary_accuracy: 0.7740
# Epoch 150/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6498 - binary_accuracy: 0.8078 - val_loss: 0.7150 - val_binary_accuracy: 0.7741
# Epoch 151/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6466 - binary_accuracy: 0.8094 - val_loss: 0.7150 - val_binary_accuracy: 0.7739
# Epoch 152/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6478 - binary_accuracy: 0.8078 - val_loss: 0.7153 - val_binary_accuracy: 0.7735
# Epoch 153/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6464 - binary_accuracy: 0.8087 - val_loss: 0.7150 - val_binary_accuracy: 0.7733
# Epoch 154/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6463 - binary_accuracy: 0.8088 - val_loss: 0.7157 - val_binary_accuracy: 0.7746
# Epoch 155/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6431 - binary_accuracy: 0.8115 - val_loss: 0.7152 - val_binary_accuracy: 0.7741
# Epoch 156/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6431 - binary_accuracy: 0.8106 - val_loss: 0.7152 - val_binary_accuracy: 0.7745
# Epoch 157/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6409 - binary_accuracy: 0.8134 - val_loss: 0.7156 - val_binary_accuracy: 0.7750
# Epoch 158/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6435 - binary_accuracy: 0.8110 - val_loss: 0.7148 - val_binary_accuracy: 0.7758
# Epoch 159/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6411 - binary_accuracy: 0.8119 - val_loss: 0.7151 - val_binary_accuracy: 0.7755
# Epoch 160/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6434 - binary_accuracy: 0.8113 - val_loss: 0.7155 - val_binary_accuracy: 0.7748
# Epoch 161/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6402 - binary_accuracy: 0.8137 - val_loss: 0.7155 - val_binary_accuracy: 0.7754
# Epoch 162/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6397 - binary_accuracy: 0.8128 - val_loss: 0.7154 - val_binary_accuracy: 0.7748
# Epoch 163/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6396 - binary_accuracy: 0.8137 - val_loss: 0.7153 - val_binary_accuracy: 0.7759
# Epoch 164/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6402 - binary_accuracy: 0.8127 - val_loss: 0.7153 - val_binary_accuracy: 0.7749
# Epoch 165/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6387 - binary_accuracy: 0.8132 - val_loss: 0.7149 - val_binary_accuracy: 0.7753
# Epoch 166/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6381 - binary_accuracy: 0.8135 - val_loss: 0.7148 - val_binary_accuracy: 0.7754
# Epoch 167/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6379 - binary_accuracy: 0.8137 - val_loss: 0.7149 - val_binary_accuracy: 0.7751
# Epoch 168/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6356 - binary_accuracy: 0.8165 - val_loss: 0.7150 - val_binary_accuracy: 0.7738
# Epoch 169/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6364 - binary_accuracy: 0.8157 - val_loss: 0.7149 - val_binary_accuracy: 0.7753
# Epoch 170/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6350 - binary_accuracy: 0.8161 - val_loss: 0.7151 - val_binary_accuracy: 0.7753
# Epoch 171/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6346 - binary_accuracy: 0.8155 - val_loss: 0.7149 - val_binary_accuracy: 0.7755
# Epoch 172/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6353 - binary_accuracy: 0.8150 - val_loss: 0.7151 - val_binary_accuracy: 0.7745
# Epoch 173/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6330 - binary_accuracy: 0.8162 - val_loss: 0.7155 - val_binary_accuracy: 0.7750
# Epoch 174/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6358 - binary_accuracy: 0.8149 - val_loss: 0.7152 - val_binary_accuracy: 0.7750
# Epoch 175/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6325 - binary_accuracy: 0.8175 - val_loss: 0.7149 - val_binary_accuracy: 0.7748
# Epoch 176/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6324 - binary_accuracy: 0.8172 - val_loss: 0.7148 - val_binary_accuracy: 0.7762
# Epoch 177/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6330 - binary_accuracy: 0.8168 - val_loss: 0.7143 - val_binary_accuracy: 0.7763
# Epoch 178/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6311 - binary_accuracy: 0.8175 - val_loss: 0.7145 - val_binary_accuracy: 0.7758
# Epoch 179/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6302 - binary_accuracy: 0.8182 - val_loss: 0.7147 - val_binary_accuracy: 0.7766
# Epoch 180/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6299 - binary_accuracy: 0.8187 - val_loss: 0.7146 - val_binary_accuracy: 0.7758
# Epoch 181/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6294 - binary_accuracy: 0.8185 - val_loss: 0.7145 - val_binary_accuracy: 0.7769
# Epoch 182/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6283 - binary_accuracy: 0.8204 - val_loss: 0.7148 - val_binary_accuracy: 0.7762
# Epoch 183/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6290 - binary_accuracy: 0.8185 - val_loss: 0.7146 - val_binary_accuracy: 0.7774
# Epoch 184/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6287 - binary_accuracy: 0.8199 - val_loss: 0.7145 - val_binary_accuracy: 0.7767
# Epoch 185/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6284 - binary_accuracy: 0.8191 - val_loss: 0.7146 - val_binary_accuracy: 0.7763
# Epoch 186/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6273 - binary_accuracy: 0.8203 - val_loss: 0.7149 - val_binary_accuracy: 0.7757
# Epoch 187/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6265 - binary_accuracy: 0.8209 - val_loss: 0.7146 - val_binary_accuracy: 0.7756
# Epoch 188/1000
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6248 - binary_accuracy: 0.8212 - val_loss: 0.7150 - val_binary_accuracy: 0.7757
# Epoch 189/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6242 - binary_accuracy: 0.8218 - val_loss: 0.7148 - val_binary_accuracy: 0.7765
# Epoch 190/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6215 - binary_accuracy: 0.8231 - val_loss: 0.7148 - val_binary_accuracy: 0.7759
# Epoch 191/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6235 - binary_accuracy: 0.8219 - val_loss: 0.7146 - val_binary_accuracy: 0.7753
# Epoch 192/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6231 - binary_accuracy: 0.8229 - val_loss: 0.7147 - val_binary_accuracy: 0.7760
# Epoch 193/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6212 - binary_accuracy: 0.8220 - val_loss: 0.7144 - val_binary_accuracy: 0.7761
# Epoch 194/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6223 - binary_accuracy: 0.8234 - val_loss: 0.7146 - val_binary_accuracy: 0.7755
# Epoch 195/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6204 - binary_accuracy: 0.8239 - val_loss: 0.7145 - val_binary_accuracy: 0.7762
# Epoch 196/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6215 - binary_accuracy: 0.8242 - val_loss: 0.7143 - val_binary_accuracy: 0.7768
# Epoch 197/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6188 - binary_accuracy: 0.8244 - val_loss: 0.7146 - val_binary_accuracy: 0.7765

# %%
history(history_resnet50)

# %%
resnet50.load_weights('weights_compare_resnet50_5.hdf5')

# %%
resnet50_predictions = (resnet50.predict(test_resnet50) >= 0.5).astype(int)

# %%
resnet50_score = f1_score(test_targets, resnet50_predictions)
print('F1 score: %.5f' % resnet50_score)
# Out:
# F1 score: 0.76888

# %% [markdown]
# ### Inception V3

# %%
from keras.applications.inception_v3 import preprocess_input

train_tensors = preprocess_input(paths_to_tensor(train_files[:nb_train]))
valid_tensors = preprocess_input(paths_to_tensor(valid_files[:nb_valid]))
test_tensors = preprocess_input(paths_to_tensor(test_files[:nb_test]))
# Out:
# 100%|████████████████████████████████████| 20000/20000 [00:40<00:00, 491.79it/s]
# 100%|██████████████████████████████████████| 2000/2000 [00:03<00:00, 551.15it/s]
# 100%|██████████████████████████████████████| 2000/2000 [00:04<00:00, 488.97it/s]

# %%
from keras.applications.inception_v3 import InceptionV3

model = InceptionV3(include_top=False)
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   96         ['conv2d[0][0]']
#  rmalization)                   32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9216        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   96         ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['activation_1[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   192        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   5120        ['max_pooling2d[0][0]']
#                                 80)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   240        ['conv2d_3[0][0]']
#  rmalization)                   80)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 80)
#
#  conv2d_4 (Conv2D)              (None, None, None,   138240      ['activation_3[0][0]']
#                                 192)
#
#  batch_normalization_10 (BatchN  (None, None, None,   576        ['conv2d_4[0][0]']
#  ormalization)                  192)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 192)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 192)
#
#  conv2d_8 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_14 (BatchN  (None, None, None,   192        ['conv2d_8[0][0]']
#  ormalization)                  64)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9216        ['max_pooling2d_1[0][0]']
#                                 48)
#
#  conv2d_9 (Conv2D)              (None, None, None,   55296       ['activation_8[0][0]']
#                                 96)
#
#  batch_normalization_12 (BatchN  (None, None, None,   144        ['conv2d_6[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_15 (BatchN  (None, None, None,   288        ['conv2d_9[0][0]']
#  ormalization)                  96)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 48)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 96)
#
#  average_pooling2d (AveragePool  (None, None, None,   0          ['max_pooling2d_1[0][0]']
#  ing2D)                         192)
#
#  conv2d_5 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76800       ['activation_6[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   82944       ['activation_9[0][0]']
#                                 96)
#
#  conv2d_11 (Conv2D)             (None, None, None,   6144        ['average_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_11 (BatchN  (None, None, None,   192        ['conv2d_5[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_13 (BatchN  (None, None, None,   192        ['conv2d_7[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_16 (BatchN  (None, None, None,   288        ['conv2d_10[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_17 (BatchN  (None, None, None,   96         ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 64)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 64)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 96)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_5[0][0]',
#                                 256)                              'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   192        ['conv2d_15[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  conv2d_13 (Conv2D)             (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_16 (Conv2D)             (None, None, None,   55296       ['activation_15[0][0]']
#                                 96)
#
#  batch_normalization_19 (BatchN  (None, None, None,   144        ['conv2d_13[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_22 (BatchN  (None, None, None,   288        ['conv2d_16[0][0]']
#  ormalization)                  96)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 48)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['mixed0[0][0]']
#  oling2D)                       256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   76800       ['activation_13[0][0]']
#                                 64)
#
#  conv2d_17 (Conv2D)             (None, None, None,   82944       ['activation_16[0][0]']
#                                 96)
#
#  conv2d_18 (Conv2D)             (None, None, None,   16384       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_18 (BatchN  (None, None, None,   192        ['conv2d_12[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_20 (BatchN  (None, None, None,   192        ['conv2d_14[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_23 (BatchN  (None, None, None,   288        ['conv2d_17[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_24 (BatchN  (None, None, None,   192        ['conv2d_18[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 64)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 64)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 96)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_12[0][0]',
#                                 288)                              'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_28 (BatchN  (None, None, None,   192        ['conv2d_22[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_23 (Conv2D)             (None, None, None,   55296       ['activation_22[0][0]']
#                                 96)
#
#  batch_normalization_26 (BatchN  (None, None, None,   144        ['conv2d_20[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_29 (BatchN  (None, None, None,   288        ['conv2d_23[0][0]']
#  ormalization)                  96)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 48)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 96)
#
#  average_pooling2d_2 (AveragePo  (None, None, None,   0          ['mixed1[0][0]']
#  oling2D)                       288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   76800       ['activation_20[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   82944       ['activation_23[0][0]']
#                                 96)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18432       ['average_pooling2d_2[0][0]']
#                                 64)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['conv2d_21[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_30 (BatchN  (None, None, None,   288        ['conv2d_24[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_31 (BatchN  (None, None, None,   192        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 64)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 96)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_19[0][0]',
#                                 288)                              'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_33 (BatchN  (None, None, None,   192        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   55296       ['activation_27[0][0]']
#                                 96)
#
#  batch_normalization_34 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  96)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 96)
#
#  conv2d_26 (Conv2D)             (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_29 (Conv2D)             (None, None, None,   82944       ['activation_28[0][0]']
#                                 96)
#
#  batch_normalization_32 (BatchN  (None, None, None,   1152       ['conv2d_26[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_35 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  96)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 384)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 96)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_26[0][0]',
#                                 768)                              'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_40 (BatchN  (None, None, None,   384        ['conv2d_34[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 128)
#
#  conv2d_35 (Conv2D)             (None, None, None,   114688      ['activation_34[0][0]']
#                                 128)
#
#  batch_normalization_41 (BatchN  (None, None, None,   384        ['conv2d_35[0][0]']
#  ormalization)                  128)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 128)
#
#  conv2d_31 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   114688      ['activation_35[0][0]']
#                                 128)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['conv2d_31[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_42 (BatchN  (None, None, None,   384        ['conv2d_36[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 128)
#
#  conv2d_32 (Conv2D)             (None, None, None,   114688      ['activation_31[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   114688      ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_38 (BatchN  (None, None, None,   384        ['conv2d_32[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_43 (BatchN  (None, None, None,   384        ['conv2d_37[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 128)
#
#  average_pooling2d_3 (AveragePo  (None, None, None,   0          ['mixed3[0][0]']
#  oling2D)                       768)
#
#  conv2d_30 (Conv2D)             (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_33 (Conv2D)             (None, None, None,   172032      ['activation_32[0][0]']
#                                 192)
#
#  conv2d_38 (Conv2D)             (None, None, None,   172032      ['activation_37[0][0]']
#                                 192)
#
#  conv2d_39 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_3[0][0]']
#                                 192)
#
#  batch_normalization_36 (BatchN  (None, None, None,   576        ['conv2d_30[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_39 (BatchN  (None, None, None,   576        ['conv2d_33[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_44 (BatchN  (None, None, None,   576        ['conv2d_38[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_45 (BatchN  (None, None, None,   576        ['conv2d_39[0][0]']
#  ormalization)                  192)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 192)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 192)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 192)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_30[0][0]',
#                                 768)                              'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_50 (BatchN  (None, None, None,   480        ['conv2d_44[0][0]']
#  ormalization)                  160)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_50[0][0]']
#                                 160)
#
#  conv2d_45 (Conv2D)             (None, None, None,   179200      ['activation_44[0][0]']
#                                 160)
#
#  batch_normalization_51 (BatchN  (None, None, None,   480        ['conv2d_45[0][0]']
#  ormalization)                  160)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_51[0][0]']
#                                 160)
#
#  conv2d_41 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_46 (Conv2D)             (None, None, None,   179200      ['activation_45[0][0]']
#                                 160)
#
#  batch_normalization_47 (BatchN  (None, None, None,   480        ['conv2d_41[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_52 (BatchN  (None, None, None,   480        ['conv2d_46[0][0]']
#  ormalization)                  160)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 160)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_52[0][0]']
#                                 160)
#
#  conv2d_42 (Conv2D)             (None, None, None,   179200      ['activation_41[0][0]']
#                                 160)
#
#  conv2d_47 (Conv2D)             (None, None, None,   179200      ['activation_46[0][0]']
#                                 160)
#
#  batch_normalization_48 (BatchN  (None, None, None,   480        ['conv2d_42[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_53 (BatchN  (None, None, None,   480        ['conv2d_47[0][0]']
#  ormalization)                  160)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 160)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_53[0][0]']
#                                 160)
#
#  average_pooling2d_4 (AveragePo  (None, None, None,   0          ['mixed4[0][0]']
#  oling2D)                       768)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_43 (Conv2D)             (None, None, None,   215040      ['activation_42[0][0]']
#                                 192)
#
#  conv2d_48 (Conv2D)             (None, None, None,   215040      ['activation_47[0][0]']
#                                 192)
#
#  conv2d_49 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_4[0][0]']
#                                 192)
#
#  batch_normalization_46 (BatchN  (None, None, None,   576        ['conv2d_40[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_49 (BatchN  (None, None, None,   576        ['conv2d_43[0][0]']
#  ormalization)                  192)
#
# ...
#
#  conv2d_82 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  conv2d_83 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  average_pooling2d_7 (AveragePo  (None, None, None,   0          ['mixed8[0][0]']
#  oling2D)                       1280)
#
#  conv2d_76 (Conv2D)             (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_84 (BatchN  (None, None, None,   1152       ['conv2d_78[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_85 (BatchN  (None, None, None,   1152       ['conv2d_79[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_88 (BatchN  (None, None, None,   1152       ['conv2d_82[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_89 (BatchN  (None, None, None,   1152       ['conv2d_83[0][0]']
#  ormalization)                  384)
#
#  conv2d_84 (Conv2D)             (None, None, None,   245760      ['average_pooling2d_7[0][0]']
#                                 192)
#
#  batch_normalization_82 (BatchN  (None, None, None,   960        ['conv2d_76[0][0]']
#  ormalization)                  320)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_84[0][0]']
#                                 384)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_85[0][0]']
#                                 384)
#
#  activation_82 (Activation)     (None, None, None,   0           ['batch_normalization_88[0][0]']
#                                 384)
#
#  activation_83 (Activation)     (None, None, None,   0           ['batch_normalization_89[0][0]']
#                                 384)
#
#  batch_normalization_90 (BatchN  (None, None, None,   576        ['conv2d_84[0][0]']
#  ormalization)                  192)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_82[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_78[0][0]',
#                                 768)                              'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_82[0][0]',
#                                 768)                              'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, None, None,   0           ['batch_normalization_90[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_76[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_95 (BatchN  (None, None, None,   1344       ['conv2d_89[0][0]']
#  ormalization)                  448)
#
#  activation_89 (Activation)     (None, None, None,   0           ['batch_normalization_95[0][0]']
#                                 448)
#
#  conv2d_86 (Conv2D)             (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_90 (Conv2D)             (None, None, None,   1548288     ['activation_89[0][0]']
#                                 384)
#
#  batch_normalization_92 (BatchN  (None, None, None,   1152       ['conv2d_86[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_96 (BatchN  (None, None, None,   1152       ['conv2d_90[0][0]']
#  ormalization)                  384)
#
#  activation_86 (Activation)     (None, None, None,   0           ['batch_normalization_92[0][0]']
#                                 384)
#
#  activation_90 (Activation)     (None, None, None,   0           ['batch_normalization_96[0][0]']
#                                 384)
#
#  conv2d_87 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_88 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_91 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  conv2d_92 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  average_pooling2d_8 (AveragePo  (None, None, None,   0          ['mixed9[0][0]']
#  oling2D)                       2048)
#
#  conv2d_85 (Conv2D)             (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_93 (BatchN  (None, None, None,   1152       ['conv2d_87[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_94 (BatchN  (None, None, None,   1152       ['conv2d_88[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_97 (BatchN  (None, None, None,   1152       ['conv2d_91[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_98 (BatchN  (None, None, None,   1152       ['conv2d_92[0][0]']
#  ormalization)                  384)
#
#  conv2d_93 (Conv2D)             (None, None, None,   393216      ['average_pooling2d_8[0][0]']
#                                 192)
#
#  batch_normalization_91 (BatchN  (None, None, None,   960        ['conv2d_85[0][0]']
#  ormalization)                  320)
#
#  activation_87 (Activation)     (None, None, None,   0           ['batch_normalization_93[0][0]']
#                                 384)
#
#  activation_88 (Activation)     (None, None, None,   0           ['batch_normalization_94[0][0]']
#                                 384)
#
#  activation_91 (Activation)     (None, None, None,   0           ['batch_normalization_97[0][0]']
#                                 384)
#
#  activation_92 (Activation)     (None, None, None,   0           ['batch_normalization_98[0][0]']
#                                 384)
#
#  batch_normalization_99 (BatchN  (None, None, None,   576        ['conv2d_93[0][0]']
#  ormalization)                  192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['batch_normalization_91[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_87[0][0]',
#                                 768)                              'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_91[0][0]',
#                                 768)                              'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, None, None,   0           ['batch_normalization_99[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_85[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
train_inception = model.predict(train_tensors)
valid_inception = model.predict(valid_tensors)
test_inception  = model.predict(test_tensors)

# %%
np.savez('yelp_inception_5.npz', 
         train_features=train_inception, train_targets=train_targets[:nb_train],
         valid_features=valid_inception, valid_targets=valid_targets[:nb_valid],
         test_features=test_inception, test_targets=test_targets[:nb_test])

# %%
bottleneck_features = np.load('yelp_inception_5.npz')
train_inception = bottleneck_features['train_features']
valid_inception = bottleneck_features['valid_features']
test_inception = bottleneck_features['test_features']

train_targets = bottleneck_features['train_targets']
valid_targets = bottleneck_features['valid_targets']
test_targets = bottleneck_features['test_targets']

# %%
inception = Sequential()
inception.add(GlobalAveragePooling2D(input_shape=train_inception.shape[1:]))

inception.add(Dense(1024, activation='relu', kernel_regularizer=l2(1e-4),
                                             bias_regularizer=l2(1e-4),
                                             activity_regularizer=l2(1e-5)))
inception.add(BatchNormalization())
inception.add(Dropout(0.3))

inception.add(Dense(512, activation='relu', kernel_regularizer=l2(1e-4),
                                             bias_regularizer=l2(1e-4),
                                             activity_regularizer=l2(1e-5)))
inception.add(BatchNormalization())
inception.add(Dropout(0.3))

inception.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4),
                                             bias_regularizer=l2(1e-4),
                                             activity_regularizer=l2(1e-5)))
inception.add(BatchNormalization())
inception.add(Dropout(0.3))

inception.add(Dense(128, activation='relu', kernel_regularizer=l2(1e-4),
                                             bias_regularizer=l2(1e-4),
                                             activity_regularizer=l2(1e-5)))
inception.add(BatchNormalization())
inception.add(Dropout(0.3))

inception.add(Dense(5, activation='sigmoid'))

inception.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_100 (Ba  (None, 1024)             4096
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  batch_normalization_101 (Ba  (None, 512)              2048
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  batch_normalization_102 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_103 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,795,525
# Trainable params: 2,791,685
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
rmsprop = tf.keras.optimizers.RMSprop(learning_rate=0.0001, momentum=0.9, epsilon=1e-06)
sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
inception.compile(loss='binary_crossentropy', optimizer=rmsprop, metrics=['binary_accuracy'])
checkpointer = ModelCheckpoint(filepath='weights_compare_inception_5.hdf5', save_best_only=True)
checkimprovement = EarlyStopping(monitor='val_binary_accuracy', min_delta=0, patience=20)

history_inception = inception.fit(train_inception, train_targets, 
                                validation_data=(valid_inception,valid_targets), 
                                epochs=1000, batch_size=128,
                                callbacks=[checkpointer,checkimprovement]
                               )
# Out:
# Epoch 1/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.9508 - binary_accuracy: 0.6583 - val_loss: 0.8086 - val_binary_accuracy: 0.7361
# Epoch 2/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.8123 - binary_accuracy: 0.7319 - val_loss: 0.7857 - val_binary_accuracy: 0.7395
# Epoch 3/1000
# 157/157 [==============================] - 2s 16ms/step - loss: 0.7748 - binary_accuracy: 0.7427 - val_loss: 0.7700 - val_binary_accuracy: 0.7446
# Epoch 4/1000
# 157/157 [==============================] - 3s 16ms/step - loss: 0.7506 - binary_accuracy: 0.7516 - val_loss: 0.7513 - val_binary_accuracy: 0.7449
# Epoch 5/1000
# 157/157 [==============================] - 3s 16ms/step - loss: 0.7321 - binary_accuracy: 0.7548 - val_loss: 0.7559 - val_binary_accuracy: 0.7385
# Epoch 6/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.7131 - binary_accuracy: 0.7601 - val_loss: 0.7627 - val_binary_accuracy: 0.7305
# Epoch 7/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6974 - binary_accuracy: 0.7625 - val_loss: 0.7202 - val_binary_accuracy: 0.7448
# Epoch 8/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6822 - binary_accuracy: 0.7658 - val_loss: 0.7159 - val_binary_accuracy: 0.7404
# Epoch 9/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6701 - binary_accuracy: 0.7688 - val_loss: 0.7129 - val_binary_accuracy: 0.7376
# Epoch 10/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6588 - binary_accuracy: 0.7687 - val_loss: 0.7082 - val_binary_accuracy: 0.7404
# Epoch 11/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6457 - binary_accuracy: 0.7705 - val_loss: 0.6844 - val_binary_accuracy: 0.7413
# Epoch 12/1000
# 157/157 [==============================] - 3s 17ms/step - loss: 0.6353 - binary_accuracy: 0.7740 - val_loss: 0.6778 - val_binary_accuracy: 0.7473
# Epoch 13/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.6280 - binary_accuracy: 0.7747 - val_loss: 0.7459 - val_binary_accuracy: 0.6999
# Epoch 14/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.6176 - binary_accuracy: 0.7755 - val_loss: 0.6686 - val_binary_accuracy: 0.7439
# Epoch 15/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.6102 - binary_accuracy: 0.7756 - val_loss: 0.6662 - val_binary_accuracy: 0.7448
# Epoch 16/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.6016 - binary_accuracy: 0.7764 - val_loss: 0.6505 - val_binary_accuracy: 0.7419
# Epoch 17/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5908 - binary_accuracy: 0.7790 - val_loss: 0.6505 - val_binary_accuracy: 0.7435
# Epoch 18/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5838 - binary_accuracy: 0.7806 - val_loss: 0.6447 - val_binary_accuracy: 0.7461
# Epoch 19/1000
# 157/157 [==============================] - 3s 16ms/step - loss: 0.5724 - binary_accuracy: 0.7833 - val_loss: 0.6329 - val_binary_accuracy: 0.7386
# Epoch 20/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5631 - binary_accuracy: 0.7859 - val_loss: 0.6563 - val_binary_accuracy: 0.7387
# Epoch 21/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5579 - binary_accuracy: 0.7867 - val_loss: 0.6354 - val_binary_accuracy: 0.7385
# Epoch 22/1000
# 157/157 [==============================] - 2s 16ms/step - loss: 0.5478 - binary_accuracy: 0.7894 - val_loss: 0.6306 - val_binary_accuracy: 0.7392
# Epoch 23/1000
# 157/157 [==============================] - 2s 16ms/step - loss: 0.5465 - binary_accuracy: 0.7866 - val_loss: 0.6779 - val_binary_accuracy: 0.7211
# Epoch 24/1000
# 157/157 [==============================] - 3s 19ms/step - loss: 0.5350 - binary_accuracy: 0.7928 - val_loss: 0.6271 - val_binary_accuracy: 0.7362
# Epoch 25/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5289 - binary_accuracy: 0.7922 - val_loss: 0.6163 - val_binary_accuracy: 0.7388
# Epoch 26/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5267 - binary_accuracy: 0.7924 - val_loss: 0.6100 - val_binary_accuracy: 0.7382
# Epoch 27/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5196 - binary_accuracy: 0.7956 - val_loss: 0.6602 - val_binary_accuracy: 0.7294
# Epoch 28/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5145 - binary_accuracy: 0.7956 - val_loss: 0.5966 - val_binary_accuracy: 0.7390
# Epoch 29/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5116 - binary_accuracy: 0.7950 - val_loss: 0.6194 - val_binary_accuracy: 0.7372
# Epoch 30/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5022 - binary_accuracy: 0.8002 - val_loss: 0.6002 - val_binary_accuracy: 0.7338
# Epoch 31/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4977 - binary_accuracy: 0.7996 - val_loss: 0.6000 - val_binary_accuracy: 0.7457
# Epoch 32/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4923 - binary_accuracy: 0.8017 - val_loss: 0.6042 - val_binary_accuracy: 0.7436

# %%
history(history_inception)

# %%
inception.load_weights('weights_compare_inception_5.hdf5')

# %%
inception_predictions = (inception.predict(test_inception) >= 0.5).astype(int)

# %%
inception_score = f1_score(test_targets, inception_predictions)
print('F1 score: %.5f' % inception_score)
# Out:
# F1 score: 0.72132
